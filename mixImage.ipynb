# %% [markdown]
# <a href="https://colab.research.google.com/github/PrithaJaipal/Introductory-CV/blob/main/mixImage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
def mixImage(imgPath1, imgPath2, mixedPath):
    img1 = cv2.imread(imgPath1)
    img2 = cv2.imread(imgPath2)
    size1 = img1.shape
    size2 = img2.shape
    height = min(size1[0], size2[0])
    width = min(size1[1], size2[1])
    print(size1)
    print(size2)
    print([height, width])
    nimg1 = cv2.resize(img1, [width, height])
    nimg2 = cv2.resize(img2, [width, height])
    img3 = cv2.addWeighted(nimg1, 0.5, nimg2, 0.5, 0)
    plt.imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))
    plt.title('Mixed Image')
    plt.axis('off')
    plt.show()
    cv2.imwrite(mixedPath, img3)

imagePath1 = '/content/img1.JPG'
imagePath2 = '/content/img2.JPG'
mixedPath = '/content/drive/MyDrive/Colab Notebooks/img3.JPG'
mixImage(imagePath1, imagePath2, mixedPath)
# Out:
# (4000, 6000, 3)
# (3000, 4496, 3)
# [3000, 4496]
